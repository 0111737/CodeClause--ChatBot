# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

# *********

# Define all variables and read GL Bot corpus file for pre-processing
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("/content/drive/MyDrive/intents.json").read()
intents = json.loads(data_file)
# *********

# preprocessing the json data
nltk.download('punkt')
nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# *********
nltk.download('omw-1.4')
# lemmatize, lower each word and remove duplicates
lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
#          */*/*/*/*/*/*/*
classes = sorted(list(set(classes)))
#          */*/*/*/*/*/*/*
# documents = combination between patterns and intents
print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)
#          */*/*/*/*/*/*/*
# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('/content/drive/MyDrive/words.pkl','wb'))
pickle.dump(classes,open('/content/drive/MyDrive/classes.pkl','wb'))
# *********

# Training the data
training = []

# create array To the output
output_empty = [0] * len(classes)
for doc in documents:
    bag = []
    pattern_words = doc[0]
    # lemmatize each word & create base word to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features & converting it into array
random.shuffle(training)
training = np.array(training)
train_x = list(training[:, 0])
train_y = list(training[:, 1])
print("Training data created")
#                         ********************////////////////*********************
# Create NN model contains 3 Layers
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot.h5', hist)
print("\nModel Created Successfully!👌")
# Out:
# 34 documents
# 7 classes ['Internship', 'codeclause', 'goodbye', 'greeting', 'offer_letter', 'options', 'thanks']
# 59 unique lemmatized words ["'s", ',', 'about', 'anyone', 'applied', 'apply', 'are', 'awesome', 'be', 'bye', 'can', 'chatting', 'codeclause', 'could', 'day', 'do', 'for', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'i', 'internship', 'is', 'later', 'letter', 'me', 'my', 'next', 'nice', 'not', 'offer', 'offered', 'provide', 'receieve', 'recieved', 'see', 'service', 'support', 'thank', 'thanks', 'that', 'the', 'there', 'till', 'time', 'to', 'what', 'when', 'where', 'will', 'you']
# Training data created
# Epoch 1/200
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 7/7 [==============================] - 1s 3ms/step - loss: 1.9941 - accuracy: 0.1471
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0365 - accuracy: 0.0882
# Epoch 3/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9233 - accuracy: 0.1765
# Epoch 4/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8747 - accuracy: 0.2353
# Epoch 5/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7907 - accuracy: 0.3824
# Epoch 6/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6751 - accuracy: 0.4412
# Epoch 7/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7261 - accuracy: 0.3235
# Epoch 8/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5304 - accuracy: 0.5588
# Epoch 9/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4949 - accuracy: 0.5882
# Epoch 10/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4426 - accuracy: 0.5882
# Epoch 11/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2914 - accuracy: 0.7353
# Epoch 12/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1585 - accuracy: 0.6471
# Epoch 13/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1230 - accuracy: 0.6176
# Epoch 14/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0803 - accuracy: 0.7353
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9539 - accuracy: 0.7941
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8386 - accuracy: 0.7647
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8476 - accuracy: 0.7941
# Epoch 18/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6436 - accuracy: 0.8235
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7250 - accuracy: 0.8235
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6840 - accuracy: 0.8529
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5541 - accuracy: 0.8824
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5217 - accuracy: 0.9118
# Epoch 23/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3885 - accuracy: 0.9412
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5848 - accuracy: 0.7941
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4441 - accuracy: 0.9118
# Epoch 26/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8824
# Epoch 27/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3516 - accuracy: 0.9412
# Epoch 28/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3537 - accuracy: 0.9412
# Epoch 29/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4010 - accuracy: 0.8529
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.9118
# Epoch 31/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3008 - accuracy: 0.9118
# Epoch 32/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3132 - accuracy: 0.9118
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3490 - accuracy: 0.9118
# Epoch 34/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3162 - accuracy: 0.9706
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 1.0000
# Epoch 36/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1602 - accuracy: 0.9706
# Epoch 37/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 1.0000
# Epoch 38/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3156 - accuracy: 0.9118
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2100 - accuracy: 0.9412
# Epoch 40/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2015 - accuracy: 0.9412
# Epoch 41/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2179 - accuracy: 1.0000
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2474 - accuracy: 0.9412
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 1.0000
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2412 - accuracy: 0.9412
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1271 - accuracy: 1.0000
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 1.0000
# Epoch 47/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1560 - accuracy: 0.9706
# Epoch 48/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1348 - accuracy: 1.0000
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 1.0000
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9412
# Epoch 51/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1928 - accuracy: 0.9706
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 1.0000
# Epoch 53/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9706
# Epoch 54/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 1.0000
# Epoch 55/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1412 - accuracy: 0.9706
# Epoch 56/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1184 - accuracy: 0.9706
# Epoch 57/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1543 - accuracy: 0.9412
# Epoch 58/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9706
# Epoch 59/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.9706
# Epoch 60/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0940 - accuracy: 0.9706
# Epoch 61/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 1.0000
# Epoch 63/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9706
# Epoch 64/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 65/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 66/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 1.0000
# Epoch 67/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.9706
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 69/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9706
# Epoch 70/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 1.0000
# Epoch 71/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9706
# Epoch 72/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2114 - accuracy: 0.9412
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 1.0000
# Epoch 74/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 0.9706
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1738 - accuracy: 0.9412
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 77/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 78/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9706
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 1.0000
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 0.9706
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 83/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 84/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 85/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 86/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9706
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 89/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 90/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0481 - accuracy: 0.9706
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9706
# Epoch 92/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 93/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 94/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 95/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0768 - accuracy: 1.0000
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 1.0000
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9706
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.9706
# Epoch 99/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 0.9706
# Epoch 100/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1047 - accuracy: 0.9412
# Epoch 101/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 1.0000
# Epoch 102/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 103/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9412
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 105/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9706
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 108/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 109/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 110/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 111/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 112/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 113/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9706
# Epoch 114/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 115/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9706
# Epoch 117/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 118/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 119/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 120/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 121/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 122/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 123/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 125/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9706
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 128/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 129/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 130/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 0.9706
# Epoch 131/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9706
# Epoch 132/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 133/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 134/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 135/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 136/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.9706
# Epoch 137/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 138/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0471 - accuracy: 0.9706
# Epoch 139/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1265 - accuracy: 0.9706
# Epoch 140/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 141/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 142/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 143/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 144/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 145/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 146/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9706
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9706
# Epoch 148/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 149/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.9412
# Epoch 150/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 151/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 152/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 153/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 154/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 155/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 156/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 157/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 158/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 159/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 161/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 162/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 163/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 165/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 166/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 168/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 169/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9706
# Epoch 170/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9706
# Epoch 171/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 172/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 173/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0489 - accuracy: 1.0000
# Epoch 174/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9706
# Epoch 175/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 176/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 177/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 178/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9706
# Epoch 179/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 180/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 181/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 182/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0911 - accuracy: 0.9706
# Epoch 183/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9706
# Epoch 184/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 0.9412
# Epoch 186/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 187/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 188/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9706
# Epoch 189/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1274 - accuracy: 0.9706
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 191/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9706
# Epoch 193/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 194/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 195/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 196/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 197/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 198/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 199/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 200/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
#
# Model Created Successfully!👌

# %%
from google.colab import drive
drive.mount('/content/drive')
